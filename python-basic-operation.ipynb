# %%
import numpy as np
a = np.array([1, 2, 3, 4, 5])#创建numpy数组
A = np.array([[1], [2], [3], [4], [5]])#创建二维numpy数组
A_1 = np.array([1,2,3,4,5,6]).reshape(2,3)#创建二维numpy数组并重塑形状
print(a.ndim)#输出数组的维度
print(a.shape)#输出数组的形状
print(a.dtype)#输出数组的数据类型
print(a.size)#输出数组的元素个数
print(len(a))#输出数组的长度


b1 = np.ones((2,3))#创建一个2行3列的全1数组
b2 = np.zeros((2,3))#创建一个2行3列的全0数组
b3 = np.empty((2,3))#创建一个2行3列的空数组
b4 = np.eye(3)#创建一个3x3的单位矩阵
b5 = np.arange(1, 10, 2)#创建一个从1到9的步长为2的数组
b6 = np.linspace(1, 10, 5)#创建一个从1到10的5个等间距的数
b7 = np.random.rand(2, 3)#创建一个2行3列的随机数组
b8 = np.random.randn(2, 3)#创建一个2行3列的标准正态分布随机数组
b9 = np.random.randint(1, 10, (2, 3))#创建一个2行3列的随机整数数组，范围从1到10
b10 = np.random.choice([1, 2, 3, 4, 5], size=(2, 3), replace=True)#创建一个2行3列的随机选择数组，允许重复选择
b11 = np.random.seed(42)  # 设置随机种子以确保结果可重复
# Out:
# 1
# (5,)
# int64
# 5
# 5

# %% [markdown]
# numpy基本操作

# %% [markdown]
# pyplot基本操作

# %%
import matplotlib.pyplot as plt
# 绘制一个简单的折线图
x = np.linspace(0, 10, 100)  # 生成从0到10的100个点
y = np.sin(x)  # 计算这些点的正弦值
plt.plot(x, y)  # 绘制折线图
plt.title('Sine Wave')  # 设置图表标题
plt.xlabel('X-axis')  # 设置X轴标签
plt.ylabel('Y-axis')  # 设置Y轴标签
plt.grid(True)  # 添加网格
plt.show()  # 显示图表

# %% [markdown]
# Pandas基本操作

# %%
import pandas as pd
# 创建一个简单的 DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)
print(df)  # 打印 DataFrame
print(df.head())  # 打印前5行
print(df.describe())  # 打印统计信息
print(df['Name'])  # 打印 Name 列
print(df[['Name', 'Age']])  # 打印 Name 和 Age 列
print(df[df['Age'] > 30])  # 打印 Age 大于30的行
print(df.sort_values(by='Age'))  # 按 Age 列排序    


dataframe = pd.read_csv('data.csv')  # 从 CSV 文件读取数据
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
#       Name  Age     City
# 2  Charlie   35  Chicago
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 18
#      14 print(df[df['Age'] > 30])  # 打印 Age 大于30的行
#      15 print(df.sort_values(by='Age'))  # 按 Age 列排序
# ---> 18 dataframe = pd.read_csv('data.csv')  # 从 CSV 文件读取数据
#
# File /opt/miniconda3/envs/environment2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/environment2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/miniconda3/envs/environment2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/environment2/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/miniconda3/envs/environment2/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'
